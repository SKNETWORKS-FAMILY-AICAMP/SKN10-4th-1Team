# %%
# !pip install py2neo
# Out:
# ...
#   Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# ...
# Using cached pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
# ...
#
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
#    -------- ------------------------------- 1/5 [pillow]
# ...

# %%
from py2neo import Graph

try:
    graph = Graph("bolt://in9045.iptime.org:7687", auth=("neo4j", "1q2w3e4r"))
    print("✅ Neo4j 연결 성공!")
    data = graph.run("MATCH (n) RETURN n LIMIT 1").data()
    print("✅ 결과:", data)
except Exception as e:
    print("❌ Neo4j 연결 실패:", e)
# Out:
# ✅ Neo4j 연결 성공!
# ...

# %%
import requests

res = requests.post(
    "http://127.0.0.1:8000/search/",
    headers={"Content-Type": "application/json"},
    json={"query": "망상병이 뭐지?", "chat_history": []}
)

print(res.status_code)
print(res.json())
# Out:
# 403
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\dev\SKN10-4th-1Team\.venv\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
